# %%
from gensim.test.utils import common_texts
print(common_texts)
# Out:
# [['human', 'interface', 'computer'], ['survey', 'user', 'computer', 'system', 'response', 'time'], ['eps', 'user', 'interface', 'system'], ['system', 'human', 'system', 'eps'], ['user', 'response', 'time'], ['trees'], ['graph', 'trees'], ['graph', 'minors', 'trees'], ['graph', 'minors', 'survey']]

# %% [markdown]
# # 一、Doc2Vec

# %%
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
# 拼接数据
documents = [TaggedDocument(doc, [i]) for i,doc in enumerate(common_texts)]
# 模型训练 --> 针对每个单词训练好对应的单词向量以及结构中的决策分类相关的特征向量
model = Doc2Vec(documents, vector_size=5, window=2, min_count=1, workers=3)

# %%
# 预测文本对应向量的时候，实际上是基于训练好的单词向量(冻结固定)，然后反向传播更新待预测文本/文档对应的特征向量
vector = model.infer_vector(["system", "response"])
print("【Doc2Vec结果】:\n{}".format(vector))

# %% [markdown]
# # 二、FastText

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from gensim import utils
from gensim.models.fasttext import FastText

word_file_path = './datas/cut_words_of_in_the_name_of_people.txt'
class MyData(object):
    def __iter__(self):
        path = word_file_path
        with open(path, 'r', encoding='utf-8') as reader:
            for line in reader:
                yield list(utils.tokenize(line))

# 模型构建
model = FastText(vector_size=4, window=3, min_count=1, sentences=MyData(), epochs=10)
# Out:
# 2026-03-14 18:53:11,897 : INFO : collecting all words and their counts
# 2026-03-14 18:53:11,898 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2026-03-14 18:53:11,980 : INFO : collected 17807 word types from a corpus of 131946 raw words and 2421 sentences
# 2026-03-14 18:53:11,981 : INFO : Creating a fresh vocabulary
# 2026-03-14 18:53:12,002 : INFO : FastText lifecycle event {'msg': 'effective_min_count=1 retains 17807 unique words (100.00% of original 17807, drops 0)', 'datetime': '2026-03-14T18:53:12.002480', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-03-14 18:53:12,002 : INFO : FastText lifecycle event {'msg': 'effective_min_count=1 leaves 131946 word corpus (100.00% of original 131946, drops 0)', 'datetime': '2026-03-14T18:53:12.002874', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-03-14 18:53:12,038 : INFO : deleting the raw counts dictionary of 17807 items
# 2026-03-14 18:53:12,039 : INFO : sample=0.001 downsamples 40 most-common words
# 2026-03-14 18:53:12,039 : INFO : FastText lifecycle event {'msg': 'downsampling leaves estimated 111168.20858219326 word corpus (84.3%% of prior 131946)', 'datetime': '2026-03-14T18:53:12.039579', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-03-14 18:53:12,114 : INFO : estimated required memory for 17807 words, 2000000 buckets and 4 dimensions: 43549128 bytes
# 2026-03-14 18:53:12,115 : INFO : resetting layer weights
# 2026-03-14 18:53:12,221 : INFO : FastText lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2026-03-14T18:53:12.221025', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'build_vocab'}
# 2026-03-14 18:53:12,221 : INFO : FastText lifecycle event {'msg': 'training model with 3 workers on 17807 vocabulary and 4 features, using sg=0 hs=0 sample=0.001 negative=5 window=3 shrink_windows=True', 'datetime': '2026-03-14T18:53:12.221525', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'train'}
# 2026-03-14 18:53:12,310 : INFO : EPOCH 0: training on 131946 raw words (111129 effective words) took 0.1s, 1257702 effective words/s
# 2026-03-14 18:53:12,394 : INFO : EPOCH 1: training on 131946 raw words (111224 effective words) took 0.1s, 1336795 effective words/s
# 2026-03-14 18:53:12,481 : INFO : EPOCH 2: training on 131946 raw words (111104 effective words) took 0.1s, 1296649 effective words/s
# 2026-03-14 18:53:12,571 : INFO : EPOCH 3: training on 131946 raw words (110971 effective words) took 0.1s, 1241932 effective words/s
# 2026-03-14 18:53:12,662 : INFO : EPOCH 4: training on 131946 raw words (111076 effective words) took 0.1s, 1233291 effective words/s
# 2026-03-14 18:53:12,750 : INFO : EPOCH 5: training on 131946 raw words (111184 effective words) took 0.1s, 1275887 effective words/s
# 2026-03-14 18:53:12,839 : INFO : EPOCH 6: training on 131946 raw words (111176 effective words) took 0.1s, 1267041 effective words/s
# 2026-03-14 18:53:12,925 : INFO : EPOCH 7: training on 131946 raw words (111143 effective words) took 0.1s, 1301413 effective words/s
# 2026-03-14 18:53:13,010 : INFO : EPOCH 8: training on 131946 raw words (111205 effective words) took 0.1s, 1321913 effective words/s
# 2026-03-14 18:53:13,097 : INFO : EPOCH 9: training on 131946 raw words (111087 effective words) took 0.1s, 1284612 effective words/s
# 2026-03-14 18:53:13,097 : INFO : FastText lifecycle event {'msg': 'training on 1319460 raw words (1111299 effective words) took 0.9s, 1268364 effective words/s', 'datetime': '2026-03-14T18:53:13.097977', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'train'}
# 2026-03-14 18:53:13,160 : INFO : FastText lifecycle event {'params': 'FastText<vocab=17807, vector_size=4, alpha=0.025>', 'datetime': '2026-03-14T18:53:13.160051', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'created'}

# %%
# 夹角余弦相似度
req_count = 5
for key in model.wv.similar_by_word('沙瑞金', topn =100):
    if len(key[0])==3:
        req_count -= 1
        print(key[0], key[1])
        if req_count == 0:
            break
# Out:
# 有用吗 0.9990224242210388
# 两秒钟 0.9982175230979919
# 孙书记 0.99802565574646
# 找育良 0.9972569942474365
# 请育良 0.9961400032043457

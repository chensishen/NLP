# %%
# import modules & set up logging
import logging

import numpy as np

import gensim
from gensim.models import word2vec

# %%
# set up logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
sentence_file_path = './datas/in_the_name_of_people.txt'
word_file_path = './datas/cut_chars_of_in_the_name_of_people.txt'
model_file_path1 = './datas/gensim_char2vec1.w2v'
model_file_path2 = './datas/gensim_char2vec2.bin'
model_file_path3 = './datas/gensim_char2vec3_{}.npy'

# %% [markdown]
# ## 一、分词

# %%
with open(word_file_path,'w', encoding='utf-8') as writer:
    with open(sentence_file_path, 'r', encoding='utf-8') as reader:
        # 加载所有数据
        content = reader.read()

        # 分词 --> 以每个字作为独立的词
        content = list(content)

        # 合并结果
        result = ' '.join(content)

        # 结果输出
        writer.write(result)
print("Done!!!")
# Out:
# Done!!!

# %% [markdown]
# ## 二、Gensim Word2Vec构建

# %% [markdown]
# #### 训练方式一

# %%
# 每行数据加载
print(f"文件路径:{word_file_path}")
sentences = word2vec.LineSentence(word_file_path)

# 训练Word2Vec模型
"""
classgensim.models.word2vec.Word2Vec(
    sentences=None, corpus_file=None,
    vector_size=100, alpha=0.025, window=5, min_count=5, max_vocab_size=None,
    sample=0.001, seed=1, workers=3, min_alpha=0.0001,
    sg=0, hs=0, negative=5, ns_exponent=0.75, cbow_mean=1,
    hashfxn=<built-in function hash>, epochs=5,
    null_word=0, trim_rule=None, sorted_vocab=1,
    batch_words=10000, compute_loss=False,
    callbacks=(), comment=None, max_final_vocab=None, shrink_windows=True)
sg: 1(Skip-gram) 0(CBOW)
hs: 1(hierarchical softmax) 0(negative)
negative: 当hs为0的时候，给定负样本数目，给定为0表示不采用负采样
"""
model = word2vec.Word2Vec(sentences, hs = 1, min_count = 1, window = 3, vector_size = 100)
# Out:
# 2026-03-13 10:54:51,307 : INFO : collecting all words and their counts
# 2026-03-13 10:54:51,309 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2026-03-13 10:54:51,348 : INFO : collected 3269 word types from a corpus of 258973 raw words and 2311 sentences
# 2026-03-13 10:54:51,349 : INFO : Creating a fresh vocabulary
# 2026-03-13 10:54:51,353 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 3269 unique words (100.00% of original 3269, drops 0)', 'datetime': '2026-03-13T10:54:51.353736', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-03-13 10:54:51,354 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 258973 word corpus (100.00% of original 258973, drops 0)', 'datetime': '2026-03-13T10:54:51.354104', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-03-13 10:54:51,361 : INFO : deleting the raw counts dictionary of 3269 items
# 2026-03-13 10:54:51,361 : INFO : sample=0.001 downsamples 69 most-common words
# 2026-03-13 10:54:51,361 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 203917.56791381162 word corpus (78.7%% of prior 258973)', 'datetime': '2026-03-13T10:54:51.361907', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-03-13 10:54:51,363 : INFO : constructing a huffman tree from 3269 words
# 2026-03-13 10:54:51,410 : INFO : built huffman tree with maximum node depth 18
# 2026-03-13 10:54:51,421 : INFO : estimated required memory for 3269 words and 100 dimensions: 6211100 bytes
# 2026-03-13 10:54:51,421 : INFO : resetting layer weights
# 2026-03-13 10:54:51,423 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2026-03-13T10:54:51.423512', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'build_vocab'}
# 2026-03-13 10:54:51,423 : WARNING : Both hierarchical softmax and negative sampling are activated. This is probably a mistake. You should set either 'hs=0' or 'negative=0' to disable one of them.
# 2026-03-13 10:54:51,423 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 3269 vocabulary and 100 features, using sg=0 hs=1 sample=0.001 negative=5 window=3 shrink_windows=True', 'datetime': '2026-03-13T10:54:51.423976', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'train'}
# 文件路径:./datas/cut_chars_of_in_the_name_of_people.txt
# 2026-03-13 10:54:51,617 : INFO : EPOCH 0: training on 258973 raw words (203978 effective words) took 0.2s, 1066075 effective words/s
# 2026-03-13 10:54:51,801 : INFO : EPOCH 1: training on 258973 raw words (203848 effective words) took 0.2s, 1116264 effective words/s
# 2026-03-13 10:54:51,984 : INFO : EPOCH 2: training on 258973 raw words (203889 effective words) took 0.2s, 1116428 effective words/s
# 2026-03-13 10:54:52,172 : INFO : EPOCH 3: training on 258973 raw words (203820 effective words) took 0.2s, 1087733 effective words/s
# 2026-03-13 10:54:52,358 : INFO : EPOCH 4: training on 258973 raw words (204040 effective words) took 0.2s, 1105481 effective words/s
# 2026-03-13 10:54:52,358 : INFO : Word2Vec lifecycle event {'msg': 'training on 1294865 raw words (1019575 effective words) took 0.9s, 1091561 effective words/s', 'datetime': '2026-03-13T10:54:52.358648', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'train'}
# 2026-03-13 10:54:52,359 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=3269, vector_size=100, alpha=0.025>', 'datetime': '2026-03-13T10:54:52.359006', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'created'}

# %% [markdown]
# #### 训练方式二

# %%
# 每行数据加载
sentences = word2vec.LineSentence(word_file_path)

# 训练Word2Vec模型
model = word2vec.Word2Vec(hs = 1,min_count = 1,window = 9,vector_size = 100)

# 构建词典
model.build_vocab(sentences)

# 模型训练
model.train(sentences, total_examples=model.corpus_count, epochs=5)
# Out:
# 2026-03-13 10:55:26,218 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=0, vector_size=100, alpha=0.025>', 'datetime': '2026-03-13T10:55:26.218277', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'created'}
# 2026-03-13 10:55:26,219 : INFO : collecting all words and their counts
# 2026-03-13 10:55:26,220 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2026-03-13 10:55:26,250 : INFO : collected 3269 word types from a corpus of 258973 raw words and 2311 sentences
# 2026-03-13 10:55:26,251 : INFO : Creating a fresh vocabulary
# 2026-03-13 10:55:26,255 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 3269 unique words (100.00% of original 3269, drops 0)', 'datetime': '2026-03-13T10:55:26.255169', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-03-13 10:55:26,255 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 258973 word corpus (100.00% of original 258973, drops 0)', 'datetime': '2026-03-13T10:55:26.255577', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-03-13 10:55:26,262 : INFO : deleting the raw counts dictionary of 3269 items
# 2026-03-13 10:55:26,263 : INFO : sample=0.001 downsamples 69 most-common words
# 2026-03-13 10:55:26,263 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 203917.56791381162 word corpus (78.7%% of prior 258973)', 'datetime': '2026-03-13T10:55:26.263491', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-03-13 10:55:26,264 : INFO : constructing a huffman tree from 3269 words
# 2026-03-13 10:55:26,309 : INFO : built huffman tree with maximum node depth 18
# 2026-03-13 10:55:26,320 : INFO : estimated required memory for 3269 words and 100 dimensions: 6211100 bytes
# 2026-03-13 10:55:26,321 : INFO : resetting layer weights
# 2026-03-13 10:55:26,323 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2026-03-13T10:55:26.323187', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'build_vocab'}
# 2026-03-13 10:55:26,323 : WARNING : Both hierarchical softmax and negative sampling are activated. This is probably a mistake. You should set either 'hs=0' or 'negative=0' to disable one of them.
# 2026-03-13 10:55:26,323 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 3269 vocabulary and 100 features, using sg=0 hs=1 sample=0.001 negative=5 window=9 shrink_windows=True', 'datetime': '2026-03-13T10:55:26.323736', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'train'}
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2026-03-13 10:55:26,545 : INFO : EPOCH 0: training on 258973 raw words (203683 effective words) took 0.2s, 926325 effective words/s
# 2026-03-13 10:55:26,757 : INFO : EPOCH 1: training on 258973 raw words (203956 effective words) took 0.2s, 967111 effective words/s
# 2026-03-13 10:55:26,970 : INFO : EPOCH 2: training on 258973 raw words (203869 effective words) took 0.2s, 958037 effective words/s
# 2026-03-13 10:55:27,189 : INFO : EPOCH 3: training on 258973 raw words (203788 effective words) took 0.2s, 936314 effective words/s
# 2026-03-13 10:55:27,411 : INFO : EPOCH 4: training on 258973 raw words (203918 effective words) took 0.2s, 920375 effective words/s
# 2026-03-13 10:55:27,412 : INFO : Word2Vec lifecycle event {'msg': 'training on 1294865 raw words (1019214 effective words) took 1.1s, 937283 effective words/s', 'datetime': '2026-03-13T10:55:27.412090', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'train'}
# (1019214, 1294865)

# %% [markdown]
# ## 三、Word2Vec应用

# %% [markdown]
# ### 0. 获取Word2Vec模型相关属性

# %%
print("【词汇数目】: {}".format(len(model.wv.key_to_index)))
print("【转换的稠密的特征向量维度数目,每个单词转换的向量维度大小】: {}".format(model.wv.vector_size))
print("【单词到id的映射关系】: \n{}".format(model.wv.key_to_index))
# Out:
# 【词汇数目】: 3269
# 【转换的稠密的特征向量维度数目,每个单词转换的向量维度大小】: 100
# 【单词到id的映射关系】:
# {'，': 0, '的': 1, '了': 2, '。': 3, '一': 4, '是': 5, '不': 6, '这': 7, '！': 8, '：': 9, '我': 10, '他': 11, '？': 12, '说': 13, '在': 14, '你': 15, '有': 16, '来': 17, '人': 18, '就': 19, '平': 20, '亮': 21, '高': 22, '个': 23, '侯': 24, '老': 25, '上': 26, '大': 27, '着': 28, '也': 29, '到': 30, '同': 31, '们': 32, '和': 33, '…': 34, '下': 35, '出': 36, '要': 37, '啊': 38, '么': 39, '长': 40, '没': 41, '地': 42, '可': 43, '还': 44, '达': 45, '子': 46, '李': 47, '康': 48, '小': 49, '得': 50, '会': 51, '时': 52, '成': 53, '事': 54, '心': 55, '道': 56, '起': 57, '书': 58, '好': 59, '记': 60, '过': 61, '手': 62, '那': 63, '看': 64, '里': 65, '话': 66, '良': 67, '想': 68, '能': 69, '育': 70, '都': 71, '明': 72, '把': 73, '去': 74, '对': 75, '陈': 76, '祁': 77, '师': 78, '伟': 79, '功': 80, '省': 81, '让': 82, '为': 83, '自': 84, '瑞': 85, '蔡': 86, '赵': 87, '局': 88, '意': 89, '然': 90, '委': 91, '现': 92, '天': 93, '学': 94, '家': 95, '情': 96, '生': 97, '中': 98, '问': 99, '发': 100, '金': 101, '头': 102,
送': 346, '亲': 347, '许': 348, '哎': 349, '抓': 350, '火': 351, '室': 352, '业': 353, '与': 354, '计': 355, '六': 356, '带': 357, '便': 358, '疑': 359, '变': 360, '五': 361, '持': 362, '审': 363, '春': 364, '转': 365, '色': 366, '台': 367, '组': 368, '秘': 369, '算': 370, '资': 371, '告': 372, '命': 373, '纪': 374, '落': 375, '示': 376, '喝': 377, '紧': 378, '呀': 379, '入': 380, '照': 381, '酒': 382, '度': 383, '通': 384, '底': 385, '内': 386, '站': 387, '错': 388, '代': 389, '息': 390, '司': 391, '苦': 392, '孙': 393, '搞': 394, '失': 395, '窗': 396, '突': 397, '断': 398, '党': 399, 'H': 400, '及': 401, '叫': 402, '满': 403, '乎': 404, '”': 405, '“': 406, '治': 407, '银': 408, '合': 409, '既': 410, ...

# %% [markdown]
# ### 1. 获取相似度最高的K个演员

# %%
# 夹角余弦相似度
req_count = 20
for key in model.wv.similar_by_word('沙', topn =100):
    req_count -= 1
    print(key[0], key[1])
    if req_count == 0:
        break
# Out:
# 龙 0.6270427107810974
# 音 0.6029228568077087
# 田 0.5512682795524597
# 惕 0.5396839380264282
# 笛 0.5201287269592285
# 插 0.4623408019542694
# 梁 0.45468658208847046
# 棺 0.442111074924469
# 罗 0.43340981006622314
# 鞅 0.43182888627052307
# 峙 0.43017980456352234
# 胖 0.42825713753700256
# 讯 0.42564505338668823
# 勃 0.4185674786567688
# 咀 0.41295063495635986
# 林 0.41257330775260925
# 金 0.41208434104919434
# 碧 0.4073261320590973
# 浸 0.40160128474235535
# 抬 0.4009021520614624

# %% [markdown]
# ### 2. 获取单词之间的相似度

# %%
# 夹角余弦相似度
print(model.wv.similarity('沙', '瑞'))
# Out:
# -0.14063488

# %%
# 夹角余弦相似度
print(model.wv.similarity('沙', '金'))
# Out:
# 0.41208425

# %% [markdown]
# ### 3. 获取单词的词向量

# %%
v1 = model.wv.get_vector("提")
print(v1.shape)
print(v1)

# %%
model.wv['提']

# %%
# 异常：不存在"明"这个单词
# model.wv.get_vector("明")

# %%
# 首先判断是否存在单词，如果存在，就返回，否则单词直接过滤
word = "明"
# word = "康"
if word in model.wv:
    print("【向量】:\n{}".format(model.wv[word]))
else:
    print("【单词不存在】!!!")
# Out:
# 【向量】:
# [-3.38162351e+00  7.68776536e-01  2.10975552e+00 -1.38558209e+00
#   2.47492385e+00  9.05612111e-01  1.91776133e+00  2.92806625e+00
#  -1.45696986e+00 -2.41346908e+00  9.37699139e-01 -1.14436284e-01
#  -6.53589964e-01 -3.67937493e+00 -1.45621049e+00 -1.33743632e+00
#  -1.17705196e-01  6.88023567e-01  9.91871595e-01 -2.27505493e+00
#  -3.58683079e-01 -1.29251373e+00 -9.37691510e-01  3.63890044e-02
#   2.46478248e+00 -1.86803961e+00  8.59532237e-01  3.23075294e+00
#   3.78931195e-01 -1.05345552e-03  7.36639798e-02  2.10106230e+00
#  -2.20701790e+00 -1.28260398e+00 -6.49529338e-01  4.03669387e-01
#  -4.03809100e-01 -5.23138463e-01 -3.18085003e+00  1.61281288e+00
#  -1.19063413e+00 -2.32230020e+00  9.57162619e-01  2.04663897e+00
#   2.11018157e+00 -5.32594800e-01 -7.94306815e-01 -1.33575737e+00
#   1.12091041e+00  3.42106402e-01  2.32960939e+00 -1.94997653e-01
#   1.69831586e+00  8.37088704e-01 -2.58238292e+00 -1.26155722e+00
#   2.09817433e+00  1.59093082e-01  8.92750740e-01 -3.05931449e-01
#  -8.30518723e-01  4.47979808e-01 -1.14608467e+00 -2.63236785e+00
#  -8.70092690e-01  7.31845498e-01 -4.45908248e-01  8.95305455e-01
#  -4.98641357e-02 -1.11604810e+00 -2.78468877e-01 -3.23426694e-01
#  -1.93516815e+00 -4.14791286e-01  1.03358537e-01 -1.04182470e+00
#   9.98248219e-01  1.81648922e+00 -3.02181114e-03 -7.12119341e-01
#  -1.26846313e+00  1.06890476e+00 -4.06056672e-01 -1.39504290e+00
#   1.69845390e+00  4.10570771e-01 -8.91062856e-01 -4.97544622e+00
#  -1.84315419e+00  1.00121021e+00  3.63774955e-01 -2.78420538e-01
#  -7.16228560e-02  1.43232000e+00  1.35469294e+00  1.94756222e+00
#   9.97132137e-02 -5.43587625e-01 -3.05810928e-01 -2.16039562e+00]

# %% [markdown]
# ## 四、模型持久化&模型恢复加载

# %% [markdown]
# ### 方式一：
# 直接使用save API进行模型持久化

# %% [markdown]
# #### 持久化

# %%
model.save(model_file_path1)
# Out:
# 2026-03-13 10:57:50,988 : INFO : Word2Vec lifecycle event {'fname_or_handle': './datas/gensim_char2vec1.w2v', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2026-03-13T10:57:50.988578', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'saving'}
# 2026-03-13 10:57:50,989 : INFO : not storing attribute cum_table
# 2026-03-13 10:57:51,009 : INFO : saved ./datas/gensim_char2vec1.w2v

# %% [markdown]
# #### 加载

# %%
# 直接基于路径加载
model2 = word2vec.Word2Vec.load(model_file_path1)
print(model2)

v1 = model2.wv.get_vector("提")
print(v1.shape)
print(v1)
# Out:
# 2026-03-13 10:58:04,137 : INFO : loading Word2Vec object from ./datas/gensim_char2vec1.w2v
# 2026-03-13 10:58:04,149 : INFO : loading wv recursively from ./datas/gensim_char2vec1.w2v.wv.* with mmap=None
# 2026-03-13 10:58:04,150 : INFO : setting ignored attribute cum_table to None
# 2026-03-13 10:58:04,168 : INFO : Word2Vec lifecycle event {'fname': './datas/gensim_char2vec1.w2v', 'datetime': '2026-03-13T10:58:04.168785', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'loaded'}
# Word2Vec<vocab=3269, vector_size=100, alpha=0.025>
# (100,)
# [-0.40237132  0.6357859  -0.7809604   0.5284837  -0.0797428   0.38691553
#  -0.4197251  -0.14210375 -0.6653569  -0.3084139  -0.34772238 -0.21032198
#   0.3606011   1.0371945  -0.12688376  0.879393   -0.51353073 -0.19189975
#  -0.46225157 -0.10273622  0.17266564 -0.55763584 -1.045527   -0.04763111
#  -0.4272047  -1.4330204  -0.53441703 -0.6147583  -0.39973328  0.8931392
#   0.41735315 -0.49701595  0.34180647  0.193356   -0.64995503 -0.5532375
#  -0.20157845  0.67715526  0.8404351   0.28835583  2.0390341   0.370151
#   0.2846509   0.57462394  0.7999049  -0.97899866  0.5032317   0.67100596
#   0.4097989  -0.050687    0.36739033  0.36897647  0.46990582 -1.1875128
#   0.40130648 -0.16978407  0.13648634  0.5829091  -0.22346666  0.15503201
#   0.22473614  0.7282738  -0.4885251   0.12880151 -0.01431437 -0.46116546
#   0.8055163   0.9145756   1.4103781  -1.2341865  -0.61826175 -0.45118836
#  -0.30993527  0.29833236 -0.8573698  -0.7866272   0.00742959 -0.40917692
#  -0.5461115  -0.39436474  1.583222   -0.93851894 -0.7720453   0.4101767
#  -0.23709546  0.57078    -0.00988793 -0.00205923  0.8246491  -0.81710374
#   0.48390007 -0.12417763  0.9000628   0.6251116  -0.04377179  0.49814463
#  -0.5590597   1.1361326  -0.16213074 -0.1122651 ]

# %% [markdown]
# ### 方式二：
# 保存为二进制词向量

# %% [markdown]
# #### 持久化

# %%
model.wv.save_word2vec_format(model_file_path2,binary=True)
# Out:
# 2026-03-13 10:58:24,156 : INFO : storing 3269x100 projection weights into ./datas/gensim_char2vec2.bin

# %% [markdown]
# #### 加载

# %%
# 加载模型
model2 = gensim.models.KeyedVectors.load_word2vec_format(model_file_path2,binary=True)
print(model2)

# 应用模型
v1 = model2.get_vector("提")
print(v1.shape)
print(v1)
# Out:
# 2026-03-13 10:58:38,015 : INFO : loading projection weights from ./datas/gensim_char2vec2.bin
# 2026-03-13 10:58:38,027 : INFO : KeyedVectors lifecycle event {'msg': 'loaded (3269, 100) matrix of type float32 from ./datas/gensim_char2vec2.bin', 'binary': True, 'encoding': 'utf8', 'datetime': '2026-03-13T10:58:38.027439', 'gensim': '4.4.0', 'python': '3.12.11 | packaged by conda-forge | (main, Jun  4 2025, 14:38:53) [Clang 18.1.8 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'load_word2vec_format'}
# KeyedVectors<vector_size=100, 3269 keys>
# (100,)
# [-0.40237132  0.6357859  -0.7809604   0.5284837  -0.0797428   0.38691553
#  -0.4197251  -0.14210375 -0.6653569  -0.3084139  -0.34772238 -0.21032198
#   0.3606011   1.0371945  -0.12688376  0.879393   -0.51353073 -0.19189975
#  -0.46225157 -0.10273622  0.17266564 -0.55763584 -1.045527   -0.04763111
#  -0.4272047  -1.4330204  -0.53441703 -0.6147583  -0.39973328  0.8931392
#   0.41735315 -0.49701595  0.34180647  0.193356   -0.64995503 -0.5532375
#  -0.20157845  0.67715526  0.8404351   0.28835583  2.0390341   0.370151
#   0.2846509   0.57462394  0.7999049  -0.97899866  0.5032317   0.67100596
#   0.4097989  -0.050687    0.36739033  0.36897647  0.46990582 -1.1875128
#   0.40130648 -0.16978407  0.13648634  0.5829091  -0.22346666  0.15503201
#   0.22473614  0.7282738  -0.4885251   0.12880151 -0.01431437 -0.46116546
#   0.8055163   0.9145756   1.4103781  -1.2341865  -0.61826175 -0.45118836
#  -0.30993527  0.29833236 -0.8573698  -0.7866272   0.00742959 -0.40917692
#  -0.5461115  -0.39436474  1.583222   -0.93851894 -0.7720453   0.4101767
#  -4.81853485e-02 -8.42507035e-02 -2.31700063e-01 -2.77504884e-03
#   3.02709956e-02  1.85428590e-01 -6.45382628e-02 -9.52085778e-02
#   3.76226418e-02 -1.74595505e-01 -1.86821469e-03  2.73377329e-01
#  -2.90656090e-01 -1.65097162e-01  1.26972899e-01  6.24788627e-02
#  -1.76095635e-01 -1.18283860e-01  5.66130355e-02  8.49238038e-03
#   1.39976144e-01 -1.29547715e-01  1.40980124e-01 -1.26483599e-02]

# %% [markdown]
# ### 方式三：
# 直接使用NumPy API保存词向量信息

# %% [markdown]
# #### 持久化

# %%
# 获取词向量
norm_word_embeddings = model.wv.get_normed_vectors()
word_embeddings = model.wv.vectors
# 获取词典(词典到idx的映射)
vocab_2_index = list(map(lambda k: (k, model.wv.key_to_index[k]), model.wv.key_to_index))
print(np.shape(norm_word_embeddings), np.shape(word_embeddings), np.shape(vocab_2_index))
# 数据保存
np.save(model_file_path3.format("norm_embedding"), norm_word_embeddings)
np.save(model_file_path3.format("embedding"), word_embeddings)
np.save(model_file_path3.format("vocab_2_index"), vocab_2_index)
# Out:
# (3269, 100) (3269, 100) (3269, 2)

# %% [markdown]
# #### 加载

# %%
# 加载数据
norm_word_embeddings = np.load(model_file_path3.format("norm_embedding"))
word_embeddings = np.load(model_file_path3.format("embedding"))
vocab_2_index = np.load(model_file_path3.format("vocab_2_index"))

# 字典转换
vocab_2_index = dict(map(lambda t:(t[0], int(t[1])), vocab_2_index))

# 获取数据
word = "提"
index = vocab_2_index[word]
v1 = word_embeddings[index]
print(v1.shape)
print(v1)
# Out:
# (100,)
# [-0.40237132  0.6357859  -0.7809604   0.5284837  -0.0797428   0.38691553
#  -0.4197251  -0.14210375 -0.6653569  -0.3084139  -0.34772238 -0.21032198
#   0.3606011   1.0371945  -0.12688376  0.879393   -0.51353073 -0.19189975
#  -0.46225157 -0.10273622  0.17266564 -0.55763584 -1.045527   -0.04763111
#  -0.4272047  -1.4330204  -0.53441703 -0.6147583  -0.39973328  0.8931392
#   0.41735315 -0.49701595  0.34180647  0.193356   -0.64995503 -0.5532375
#  -0.20157845  0.67715526  0.8404351   0.28835583  2.0390341   0.370151
#   0.2846509   0.57462394  0.7999049  -0.97899866  0.5032317   0.67100596
#   0.4097989  -0.050687    0.36739033  0.36897647  0.46990582 -1.1875128
#   0.40130648 -0.16978407  0.13648634  0.5829091  -0.22346666  0.15503201
#   0.22473614  0.7282738  -0.4885251   0.12880151 -0.01431437 -0.46116546
#   0.8055163   0.9145756   1.4103781  -1.2341865  -0.61826175 -0.45118836
#  -0.30993527  0.29833236 -0.8573698  -0.7866272   0.00742959 -0.40917692
#  -0.5461115  -0.39436474  1.583222   -0.93851894 -0.7720453   0.4101767
#  -0.23709546  0.57078    -0.00988793 -0.00205923  0.8246491  -0.81710374
#   0.48390007 -0.12417763  0.9000628   0.6251116  -0.04377179  0.49814463
#  -0.5590597   1.1361326  -0.16213074 -0.1122651 ]
